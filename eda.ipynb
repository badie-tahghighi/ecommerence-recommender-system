# %%
import pandas as pd

interactions = pd.read_csv('assets/csv/interactions_dataset.csv')

# %%
import seaborn

seaborn.countplot(y='interaction_type', data=interactions, orient='h', hue='value')
# Out:
# <AxesSubplot: xlabel='count', ylabel='interaction_type'>

# %%
reviews = pd.read_csv('assets/csv/reviews_dataset.csv')

seaborn.countplot(x='rate', data=reviews)
# Out:
# <AxesSubplot: xlabel='rate', ylabel='count'>

# %%
users = pd.read_csv('assets/csv/users_dataset.csv')
seaborn.countplot(x='gender', data=users)
# Out:
# <AxesSubplot: xlabel='gender', ylabel='count'>

# %%
seaborn.distplot(users['age'])
# Out:
# C:\Users\Gustav\AppData\Local\Temp\ipykernel_13708\4273045597.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(users['age'])
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
seaborn.distplot(users['balance'])
# Out:
# C:\Users\Gustav\AppData\Local\Temp\ipykernel_13708\967148797.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(users['balance'])
# <AxesSubplot: xlabel='balance', ylabel='Density'>

# %%
seaborn.countplot(x='marriage_status', data=users)
# Out:
# <AxesSubplot: xlabel='marriage_status', ylabel='count'>
